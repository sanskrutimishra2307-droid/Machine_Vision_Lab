# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskrutimishra2307-droid/Machine_Vision_Lab/blob/main/Mv01_016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf4ba96e-5c69-4758-995d-cb4c5e236448" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf4ba96e-5c69-4758-995d-cb4c5e236448">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image = cv2.imread(list(uploaded.keys())[0])

# Convert BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6,6))
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
equalized = cv2.equalizeHist(gray)

plt.figure(figsize=(6,6))
plt.imshow(equalized, cmap='gray')
plt.title("Histogram Equalization")
plt.axis("off")
plt.show()

# %%
brightness = cv2.convertScaleAbs(equalized,
                                 alpha=1.2,
                                 beta=40)

plt.imshow(brightness, cmap='gray')
plt.title("Brightness Enhanced")
plt.axis("off")
plt.show()

# %%
median = cv2.medianBlur(brightness,5)

plt.imshow(median, cmap='gray')
plt.title("Noise Removed")
plt.axis("off")
plt.show()

# %%
gaussian = cv2.GaussianBlur(median,(5,5),0)

plt.imshow(gaussian, cmap='gray')
plt.title("Gaussian Filter")
plt.axis("off")
plt.show()

# %%
titles = [
    "Original",
    "Gray",
    "Histogram Equalization",
    "Brightness Enhanced",
    "Median Filter",
    "Gaussian Filter"
]

images = [
    image_rgb,
    gray,
    equalized,
    brightness,
    median,
    gaussian
]

plt.figure(figsize=(16,8))

for i in range(6):
    plt.subplot(2,3,i+1)

    if len(images[i].shape)==2:
        plt.imshow(images[i], cmap='gray')
    else:
        plt.imshow(images[i])

    plt.title(titles[i])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
cv2.imwrite("Enhanced_CCTV.jpg", gaussian)

files.download("Enhanced_CCTV.jpg")
